# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.histplot(x = df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.distplot(x = df['bmi'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.histplot(x = df['charges'])
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Count'>

# %%
correlation = df.corr()
correlation
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.regplot(x = df['age'], y = df['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.regplot(x = df['bmi'], y = df['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.boxplot(x = df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x = df['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.distplot(x = df['bmi'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = df.drop("charges", axis = 1)
x.head()
# Out:
#    age     sex     bmi  children smoker     region
# 0   19  female  27.900         0    yes  southwest
# 1   18    male  33.770         1     no  southeast
# 2   28    male  33.000         3     no  southeast
# 3   33    male  22.705         0     no  northwest
# 4   32    male  28.880         0     no  northwest

# %%
y = df['charges']
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
x = pd.get_dummies(x, drop_first = True)
x
# Out:
#       age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19  27.900         0         0           1                 0
# 1      18  33.770         1         1           0                 0
# 2      28  33.000         3         1           0                 0
# 3      33  22.705         0         1           0                 1
# 4      32  28.880         0         1           0                 1
# ...   ...     ...       ...       ...         ...               ...
# 1333   50  30.970         3         1           0                 1
# 1334   18  31.920         0         0           0                 0
# 1335   18  36.850         0         0           0                 0
# 1336   21  25.800         0         0           0                 0
# 1337   61  29.070         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 8 columns]

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
x.describe()
# Out:
#                age          bmi     children     sex_male   smoker_yes  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025    30.663397     1.094918     0.505232     0.204783
# std      14.049960     6.098187     1.205493     0.500160     0.403694
# min      18.000000    15.960000     0.000000     0.000000     0.000000
# 25%      27.000000    26.296250     0.000000     0.000000     0.000000
# 50%      39.000000    30.400000     1.000000     1.000000     0.000000
# 75%      51.000000    34.693750     2.000000     1.000000     0.000000
# max      64.000000    53.130000     5.000000     1.000000     1.000000
#
#        region_northwest  region_southeast  region_southwest
# count       1338.000000       1338.000000       1338.000000
# mean           0.242900          0.272048          0.242900
# std            0.428995          0.445181          0.428995
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000          1.000000          0.000000
# max            1.000000          1.000000          1.000000

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train[['age', 'bmi']] = sc.fit_transform(x_train[['age','bmi']])
x_test[['age','bmi']] = sc.fit_transform(x_test[['age','bmi']])
# Out:
# <ipython-input-9-bc58b55710f7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train[['age', 'bmi']] = sc.fit_transform(x_train[['age','bmi']])
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# <ipython-input-9-bc58b55710f7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[['age','bmi']] = sc.fit_transform(x_test[['age','bmi']])
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
x_train.describe()
# Out:
#                 age           bmi     children     sex_male   smoker_yes  \
# count  1.003000e+03  1.003000e+03  1003.000000  1003.000000  1003.000000
# mean   2.087618e-16  1.096248e-16     1.104686     0.504487     0.205384
# std    1.000499e+00  1.000499e+00     1.204619     0.500229     0.404183
# min   -1.514757e+00 -2.421218e+00     0.000000     0.000000     0.000000
# 25%   -8.733711e-01 -7.157574e-01     0.000000     0.000000     0.000000
# 50%   -1.818931e-02 -5.187588e-02     1.000000     1.000000     0.000000
# 75%    8.369925e-01  6.519384e-01     2.000000     1.000000     0.000000
# max    1.763439e+00  3.763363e+00     5.000000     1.000000     1.000000
#
#        region_northwest  region_southeast  region_southwest
# count       1003.000000       1003.000000       1003.000000
# mean           0.245264          0.258225          0.246261
# std            0.430458          0.437877          0.431047
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000
# 109     47055.53210
# 575     12222.89830
# 535      6067.12675
# 543     63770.42801
# 846      9872.70100
# Name: charges, Length: 268, dtype: float64

# %%
y_pred_ds = pd.DataFrame(y_pred, columns = ['Predicted Values'])
y_pred_ds
# Out:
#      Predicted Values
# 0         9084.373760
# 1         7095.977905
# 2        36995.325549
# 3         9564.117937
# 4        26933.856230
# ..                ...
# 263      39084.117009
# 264      11880.185471
# 265       7746.784398
# 266      40753.362713
# 267      12324.659005
#
# [268 rows x 1 columns]

# %%
y_test_ds = pd.DataFrame(np.array(y_test), columns = ["Actual Values"])
y_test_ds
# Out:
#      Actual Values
# 0       9095.06825
# 1       5272.17580
# 2      29330.98315
# 3       9301.89355
# 4      33750.29180
# ..             ...
# 263    47055.53210
# 264    12222.89830
# 265     6067.12675
# 266    63770.42801
# 267     9872.70100
#
# [268 rows x 1 columns]

# %%
pd.concat([y_test_ds,y_pred_ds], axis = 1)
# Out:
#      Actual Values  Predicted Values
# 0       9095.06825       9084.373760
# 1       5272.17580       7095.977905
# 2      29330.98315      36995.325549
# 3       9301.89355       9564.117937
# 4      33750.29180      26933.856230
# ..             ...               ...
# 263    47055.53210      39084.117009
# 264    12222.89830      11880.185471
# 265     6067.12675       7746.784398
# 266    63770.42801      40753.362713
# 267     9872.70100      12324.659005
#
# [268 rows x 2 columns]

# %%
plt.title("Relation between the Actual values and Predicted Values")
sns.regplot(x = y_test_ds['Actual Values'], y = y_pred_ds['Predicted Values'])
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error
score = r2_score(y_test, y_pred)
print("R2 Score : {}".format(score))
print("Model Accuracy: {}%".format(score * 100))
# Out:
# R2 Score : 0.7836576015821692
# Model Accuracy: 78.36576015821693%

# %%
# Assumptions of Multi Linear Regression 
In order to validated model we need to check few assumption of linear regression model. The common assumption for Linear Regression model are following

Linear Relationship: In linear regression the relationship between the dependent and independent variable to be linear. This can be checked by scatter ploting Actual value Vs Predicted value
The residual error plot should be normally distributed.
The mean of residual error should be 0 or close to 0 as much as possible
The linear regression require all variables to be multivariate normal. This assumption can best checked with Q-Q plot.
Linear regession assumes that there is little or no Multicollinearity in the data. Multicollinearity occurs when the independent variables are too highly correlated with each other. The variance inflation factor VIF* identifies correlation between independent variables and strength of that correlation.  VIF=11−R2 , If VIF >1 & VIF <5 moderate correlation, VIF < 5 critical level of multicollinearity.
Homoscedasticity: The data are homoscedastic meaning the residuals are equal across the regression line. We can look at residual Vs fitted value scatter plot. If heteroscedastic plot would exhibit a funnel shape pattern.

# %%
#check for Linearity
plt.title("Relation between the Actual values and Predicted Values")
sns.scatterplot(x = y_test_ds['Actual Values'], y = y_pred_ds['Predicted Values'])
plt.show()

# %%
#Check for Residual Normality & Mean
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(121)
sns.distplot((y_test - y_pred), ax = ax,  color = 'b')
ax.axvline((y_test - y_pred).mean(),color='k',linestyle='--')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Check for Homoscedasticity
sns.scatterplot(y = (y_test - y_pred), x= y_pred, color='r')
# Out:
# <AxesSubplot:ylabel='charges'>

# %%
# Check for Multicollinearity
#Variance Inflation Factor
VIF = 1/(1- score)
VIF
# Out:
# 4.622302458109297

# %%
The model assumption linear regression as follows

In our model the actual vs predicted plot is curve so linear assumption fails
The residual mean is zero and residual error plot right skewed
Q-Q plot shows as value log value greater than 1.5 trends to increase
The plot is exhibit heteroscedastic, error will insease after certian point.
Variance inflation factor value is less than 5, so no multicollearity.
